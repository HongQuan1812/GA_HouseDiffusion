# %% [markdown]
# # Setup

# %%
import os
import sys
import shutil

def remove_folder(path):
    if os.path.exists(path):
        shutil.rmtree(path)

# %%
# !git clone https://github.com/aminshabani/house_diffusion.git /kaggle/working/HOUSE_DIFFUSION_DIFFUSION

# %% [markdown]
# # Data - Preprocess

# %%
# %cd /kaggle/working
# !git clone https://github.com/sepidsh/Housegan-data-reader.git

# %%
# !pip install gdown

# %%
# !sudo apt-get install unrar

# %%
# !gdown 1roWsHejGZIzawa_KtB4dpquFnjl9w71R -O /kaggle/working/dataset.rar

# %%
# !unrar x /kaggle/working/dataset.rar
# !mv /kaggle/working/dataset /kaggle/working/Housegan-data-reader/rplan_dataset

# %%
def pre_process_data(limit = None):
    # %cd /kaggle/working/Housegan-data-reader
    if limit == None:
          # !python3 /kaggle/working/Housegan-data-reader/run.py
    else:
          # !python3 /kaggle/working/Housegan-data-reader/run.py --limit '{limit}'

    if os.path.exists("/kaggle/working/HOUSE_DIFFUSION_DIFFUSION/datasets"):
        remove_folder("/kaggle/working/HOUSE_DIFFUSION_DIFFUSION/datasets")
    remove_folder("/kaggle/working/Housegan-data-reader/failed_rplan_json")

    # %mkdir /kaggle/working/HOUSE_DIFFUSION_DIFFUSION/datasets
    # %mv /kaggle/working/Housegan-data-reader/rplan_json /kaggle/working/HOUSE_DIFFUSION_DIFFUSION/datasets/rplan

# %%
pre_process_data(5000)
